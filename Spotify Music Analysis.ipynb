# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
music_data = pd.read_csv('C:\\Users\\Admin\\Downloads\\high_popularity_spotify_data.csv')
music_data
# Out:
#       energy    tempo  danceability playlist_genre  loudness  liveness  \
# 0      0.592  157.969         0.521            pop    -7.777    0.1220
# 1      0.507  104.978         0.747            pop   -10.171    0.1170
# 2      0.808  108.548         0.554            pop    -4.169    0.1590
# 3      0.910  112.966         0.670            pop    -4.070    0.3040
# 4      0.783  149.027         0.777            pop    -4.477    0.3550
# ...      ...      ...           ...            ...       ...       ...
# 1681   0.422  124.357         0.573          latin    -7.621    0.1020
# 1682   0.725  105.016         0.711          latin    -8.315    0.1100
# 1683   0.809   99.005         0.724          latin    -5.022    0.0765
# 1684   0.642   83.389         0.463          latin    -4.474    0.0686
# 1685   0.890  126.881         0.645            pop    -4.985    0.3760
#
#       valence               track_artist  time_signature  speechiness  ...  \
# ...

# %%
music_data.head(5)
# Out:
#    energy    tempo  danceability playlist_genre  loudness  liveness  valence  \
# 0   0.592  157.969         0.521            pop    -7.777     0.122    0.535
# 1   0.507  104.978         0.747            pop   -10.171     0.117    0.438
# 2   0.808  108.548         0.554            pop    -4.169     0.159    0.372
# 3   0.910  112.966         0.670            pop    -4.070     0.304    0.786
# 4   0.783  149.027         0.777            pop    -4.477     0.355    0.939
#
#             track_artist  time_signature  speechiness  ...  instrumentalness  \
# 0  Lady Gaga, Bruno Mars               3       0.0304  ...            0.0000
# 1          Billie Eilish               4       0.0358  ...            0.0608
# 2          Gracie Abrams               4       0.0368  ...            0.0000
# 3      Sabrina Carpenter               4       0.0634  ...            0.0000
# 4       ROSÉ, Bruno Mars               4       0.2600  ...            0.0000
#
# ...

# %%
music_data.sample(5)
# Out:
#       energy    tempo  danceability playlist_genre  loudness  liveness  \
# 1406   0.626  100.020         0.763          latin    -5.637    0.2050
# 1631   0.731   97.007         0.751           rock    -4.419    0.0556
# 729    0.411  169.934         0.584          latin    -7.147    0.0955
# 685    0.247  148.101         0.467            pop   -12.002    0.1700
# 472    0.471  105.029         0.472         gaming    -5.692    0.1400
#
#       valence   track_artist  time_signature  speechiness  ...  \
# 1406    0.780        Cris Mj               4       0.0433  ...
# 1631    0.973         Juanes               4       0.0308  ...
# 729     0.412      Bad Bunny               4       0.0838  ...
# 685     0.126  Billie Eilish               4       0.0431  ...
# 472     0.219   Benson Boone               3       0.0603  ...
#
#       instrumentalness          track_album_id mode key duration_ms  \
# 1406          0.225000  4ecjQGViGCD4snnZ3QJOEL    0   5      156171
# ...

# %%
music_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1686 entries, 0 to 1685
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   energy                    1686 non-null   float64
#  1   tempo                     1686 non-null   float64
#  2   danceability              1686 non-null   float64
#  3   playlist_genre            1686 non-null   object
#  4   loudness                  1686 non-null   float64
#  5   liveness                  1686 non-null   float64
#  6   valence                   1686 non-null   float64
#  7   track_artist              1686 non-null   object
#  8   time_signature            1686 non-null   int64
#  9   speechiness               1686 non-null   float64
#  10  track_popularity          1686 non-null   int64
#  11  track_href                1686 non-null   object
#  12  uri                       1686 non-null   object
# ...

# %%
music_data.duplicated().sum()
# Out:
# 0

# %%
music_data.isnull().sum()
# Out:
# energy                      0
# tempo                       0
# danceability                0
# playlist_genre              0
# loudness                    0
# liveness                    0
# valence                     0
# track_artist                0
# time_signature              0
# speechiness                 0
# track_popularity            0
# track_href                  0
# uri                         0
# track_album_name            1
# playlist_name               0
# analysis_url                0
# track_id                    0
# track_name                  0
# track_album_release_date    0
# instrumentalness            0
# track_album_id              0
# mode                        0
# key                         0
# duration_ms                 0
# acousticness                0
# id                          0
# playlist_subgenre           0
# type                        0
# playlist_id                 0
# dtype: int64

# %%
music_data['playlist_genre'].unique()
# Out:
# array(['pop', 'rock', 'jazz', 'classical', 'hip-hop', 'afrobeats',
#        'latin', 'indian', 'country', 'r&b', 'electronic', 'soul',
#        'gaming', 'j-pop', 'metal', 'reggae', 'k-pop', 'arabic', 'punk',
#        'blues', 'folk', 'lofi', 'brazilian', 'turkish', 'ambient',
#        'korean', 'world', 'indie'], dtype=object)

# %%
order_genre = music_data['playlist_genre'].value_counts().index 
sns.countplot(data=music_data, x='playlist_genre', order=order_genre)
plt.xticks(rotation=90)
plt.xlabel('Music Genre')
plt.ylabel('Number of Songs')
plt.title('Number of Songs per Music Genre')
plt.show()

# %%
music_data['playlist_genre'].value_counts()
# Out:
# playlist_genre
# pop           357
# rock          235
# hip-hop       227
# latin         184
# electronic    148
# gaming        100
# ambient        61
# punk           50
# arabic         50
# r&b            50
# blues          45
# metal          35
# folk           33
# afrobeats      20
# brazilian      14
# j-pop          11
# k-pop          11
# classical      10
# indian          9
# korean          8
# turkish         7
# reggae          5
# world           4
# indie           4
# country         3
# soul            2
# lofi            2
# jazz            1
# Name: count, dtype: int64

# %%
music_data['playlist_subgenre'].unique()
# Out:
# array(['mainstream', 'classic', 'essential', 'modern', 'gangster', 'trap',
#        'nigerian', 'hip-hop', 'bollywood', 'indie', 'feel-good',
#        'african', 'anime', '90s', '80s', 'french', 'global', 'chill',
#        'soft', 'throwback', 'bedroom', 'alternative', 'heavy', 'death',
#        'pop punk', 'southern', 'american', 'bhangra', 'tropical',
#        'techno', 'future bass', 'deep house', 'cumbia', 'reggaeton',
#        'funk', 'pop', 'meditative', 'academic', 'melodic', 'drama',
#        'throat singing', 'nordic', 'desi', 'fusion', 'afro house',
#        'neo-classical', 'vaporwave', 'drill', 'spanish', 'workout',
#        'australian', 'afro-latin', 'scandi'], dtype=object)

# %%
order_subgenre = music_data['playlist_subgenre'].value_counts().head(15).index 
sns.countplot(data=music_data, x='playlist_subgenre', order=order_subgenre)
plt.xticks(rotation=90)
plt.xlabel('Music Subgenreenre')
plt.ylabel('Number of Songs')
plt.title('Number of Songs per Music Subgenre')
plt.show()

# %%
print(f"There are {music_data.index.size} recorded songs.")
# Out:
# There are 1686 recorded songs.

# %%
music_data[['track_name','track_artist','track_popularity','playlist_name']].sort_values(by='track_popularity', ascending=False)
# Out:
#                      track_name                               track_artist  \
# 0              Die With A Smile                      Lady Gaga, Bruno Mars
# 676            Die With A Smile                      Lady Gaga, Bruno Mars
# 455            Die With A Smile                      Lady Gaga, Bruno Mars
# 677                        APT.                           ROSÉ, Bruno Mars
# 4                          APT.                           ROSÉ, Bruno Mars
# ...                         ...                                        ...
# 244               Un Ratito Mas                    Bryant Myers, Bad Bunny
# 733               Tacones Rojos                            Sebastian Yatra
# 730                  Tan Bonita                                    Piso 21
# 1583                Knife Brows                           Dhanda Nyoliwala
# 309   Ranjha (From "Shershaah")  Jasleen Royal, B Praak, Romy, Anvita Dutt
#
#       track_popularity        playlist_name
# ...

# %%
music_data['track_artist'].value_counts()
# Out:
# track_artist
# Bad Bunny                    20
# Linkin Park                  14
# Sabrina Carpenter            11
# Hozier                       11
# Billie Eilish                10
#                              ..
# NewJeans                      1
# NCT DREAM                     1
# Wham!                         1
# Lord Huron                    1
# Alan Walker, Ina Wroldsen     1
# Name: count, Length: 1033, dtype: int64

# %%
columns_corr = ['energy', 'tempo', 'danceability', 'loudness', 'valence','time_signature', 'speechiness', 'track_popularity', 
           'key', 'duration_ms', 'acousticness']
correlation = music_data[columns_corr].corr()

# %%
sns.heatmap(correlation, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
columns_pcorr = ['energy', 'tempo', 'danceability', 'loudness', 'valence', 'speechiness']
pcorrelation = music_data[columns_pcorr].corr()
sns.heatmap(pcorrelation, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
genre_popularity_order = music_data.groupby('playlist_genre')['track_popularity'].mean().sort_values(ascending=False).index

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='playlist_genre',y='track_popularity',data=music_data, order=genre_popularity_order, showmeans=True)
plt.title('Variation of Track Popularity by Genre')
plt.xlabel('Music Genre')
plt.ylabel('Track Popularity')
plt.show()

# %%
genre_energy_order = music_data.groupby('playlist_genre')['energy'].mean().sort_values(ascending=False).index

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='playlist_genre',y='energy',data= music_data, order=genre_energy_order, showmeans=True)
plt.title('Variation of Track Energy by Genre')
plt.xlabel('Music Genre')
plt.ylabel('Track Energy')
plt.show()

# %%
genre_danceability_order = music_data.groupby('playlist_genre')['danceability'].mean().sort_values(ascending=False).index
plt.figure(figsize=(20,10))
sns.boxplot(x='playlist_genre',y='danceability',data=music_data, order=genre_danceability_order, showmeans=True)
plt.title('Variation of Track Danceability by Genre')
plt.xlabel('Music Genre')
plt.ylabel('Track Danceability')
plt.show()

# %%
genre_loudness_order = music_data.groupby('playlist_genre')['loudness'].mean().sort_values(ascending=False).index
plt.figure(figsize=(20,10))
sns.boxplot(x='playlist_genre',y='loudness',data=music_data, order=genre_loudness_order, showmeans=True)
plt.title('Variation of Track Loudness by Genre')
plt.xlabel('Music Genre')
plt.ylabel('Track Loudness')
plt.show()

# %%
genre_duration_order = music_data.groupby('playlist_genre')['duration_ms'].mean().sort_values(ascending=False).index
plt.figure(figsize=(20,10))
sns.boxplot(x='playlist_genre',y='duration_ms',data=music_data, order=genre_duration_order, showmeans=True)
plt.title('Variation of Track Duration by Genre')
plt.xlabel('Music Genre')
plt.ylabel('Track Duration')
plt.show()

# %%
subgenre_popularity_order = music_data.groupby('playlist_subgenre')['track_popularity'].mean().sort_values(ascending=False).index
plt.figure(figsize=(20,10))
sns.boxplot(x='playlist_subgenre',y='track_popularity',data=music_data, order=subgenre_popularity_order, showmeans=True)
plt.title('Variation of Track Duration by SubGenre')
plt.xlabel('Music SubGenre')
plt.ylabel('Track Popularity')
plt.xticks(rotation=90)
plt.show()
